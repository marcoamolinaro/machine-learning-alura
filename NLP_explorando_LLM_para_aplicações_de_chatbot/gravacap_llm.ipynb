# %%
# !pip install litellm
# Out:
# Collecting litellm
#   Downloading litellm-1.78.0-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm) (3.13.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm) (8.3.0)
# Collecting fastuuid>=0.13.0 (from litellm)
#   Downloading fastuuid-0.13.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (4.25.1)
# Requirement already satisfied: openai>=1.99.5 in /usr/local/lib/python3.12/dist-packages (from litellm) (1.109.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (2.11.10)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (1.1.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm) (0.22.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.27.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm) (0.11.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm) (2.32.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm) (0.35.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (2.5.0)
# Downloading litellm-1.78.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 56.9 MB/s eta 0:00:00
# Downloading fastuuid-0.13.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: fastuuid, litellm
# Successfully installed fastuuid-0.13.5 litellm-1.78.0

# %%
from google.colab import userdata
QROQ_API_KEY = userdata.get('QROQ_API_KEY')

# %%
from litellm import completion

# %%
messages = [
    {"role": "system", "content": "Você é o chat da Terra e do Universo, que responde perguntas em português brasileiro sobre previsão do tempo na Terra e no espaço próximo à Terra, além de informações sobre terremotos."},
    {"role": "user", "content": "Qual a frequência dos máximos solares?"},
]

# %%
response = completion(
    model="groq/llama-3.3-70b-versatile",
    messages=messages,
    api_key=QROQ_API_KEY
)

# %%
print(response.choices[0].message.content)
# Out:
# Os máximos solares ocorrem aproximadamente a cada 11 anos, embora possam variar entre 9 e 14 anos. Esse ciclo é conhecido como o ciclo de Schwabe, em homenagem ao astrônomo alemão Heinrich Schwabe, que foi o primeiro a observar e registrar o padrão de variação da atividade solar.
#
# Durante um máximo solar, a atividade solar aumenta significativamente, com mais manchas solares, erupções solares e ejeções de massa coronal. Isso pode afetar a magnetosfera da Terra e causar auroras mais frequentes e intensas.
#
# O ciclo de Schwabe é influenciado pela rotação do Sol e pela dinâmica do seu interior. A variação na atividade solar durante o ciclo de Schwabe pode ter implicações nos campos magnéticos terrestre e solar, bem como na formação de auroras e na propagação de ondas de rádio.
#
# Aqui está uma lista dos últimos máximos solares:
#
# * Máximo solar de 2025 (previsto)
# * Máximo solar de 2014 (ciclo 24)
# * Máximo solar de 2001 (ciclo 23)
# * Máximo solar de 1990 (ciclo 22)
# * Máximo solar de 1979 (ciclo 21)
#
# Lembre-se de que a previsão dos máximos solares ainda é uma área de pesquisa ativa e pode haver variações nos padrões de atividade solar.

# %%
response = completion(
    model="groq/llama-3.1-8b-instant",
    messages=messages,
    api_key=QROQ_API_KEY
)
# Out:
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Os máxi...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(

# %%
print(response.choices[0].message.content)
# Out:
# Os máximos solares são periodicamente ocorridos e definidos por um ciclo. O ciclo do Sol é conhecido como Ciclo Solare (ou ciclo de Maunder). Esse ciclo tem uma duração média de 11 anos, mas pode variar de 9 a 14 anos. Durante esse ciclo, o campo magnético do Sol se fortalece e se enfraquece, e a atividade solar aumenta e diminui.
#
# Os máximos solares ocorrem quando o campo magnético do Sol está em seu pico de atividade, o que geralmente leva a mais frequentes surtos de raios cósmicos e ações solares, além de terremotos. Em média, ocorrem 2-3 máximos solares por ciclo, espaçados a 3-4 anos um do outro.
#
# No entanto, é importante lembrar que os ciclos solares podem variar de intensidade, e alguns máximos solares podem ser mais fortes ou mais fracos do que outros.
#
# Se você está procurando saber quando será o próximo máximo solar, posso fornecer mais informações sobre o ciclo atual do Sol. O ciclo solar atual é o Ciclo Solare 25 (SC25) e, de acordo com as previsões, o próximo máximo solar ocorrerá em algum momento entre 2023 e 2024.

# %%
def call_groq_api(messages, model="groq/llama-3.3-70b-versatile"):
    response = completion(
        model=model,
        messages=messages,
        api_key=QROQ_API_KEY,
    )
    return response.choices[0].message.content

# %%
def chat():
    print("Iniciando chat com o modelo. Digite 'sair' para encerrar.")
    messages = [
        {"role": "system", "content": "Você é o Chat da Terra e do Universo e responde em português brasileiro perguntas sobre a previsão do tempo na Terra e do espaço próximo à Terra, além de informações sobre terremotos."}
    ]

    while True:
        user_message = input("Você: ")
        if user_message.lower() == "sair":
            print("Encerrando chat. Até a próxima!")
            break
        messages.append({"role": "user", "content": user_message})
        model_response = call_groq_api(messages)
        messages.append({"role": "assistant", "content": model_response})
        print(f"Assistente: {model_response}")

# %%
chat()
# Out:
# Iniciando chat com o modelo. Digite 'sair' para encerrar.
# Você: Qual a previsão do tempo para amanhã no Rio de Janeiro?
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content='A previs...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Assistente: A previsão do tempo pode variar de acordo com a fonte e o modelo utilizado. No entanto, posso fornecer uma visão geral da previsão do tempo para o Rio de Janeiro com base em dados disponíveis até minha última atualização em 2023.
#
# Para obter a previsão do tempo mais atualizada e precisa para amanhã no Rio de Janeiro, recomendo consultar um serviço de previsão do tempo confiável, como o Instituto Nacional de Meteorologia (INMET) ou serviços de meteorologia online, como o AccuWeather, Weather.com, ou o ClimaTempo.
#
# Geralmente, o Rio de Janeiro tem um clima tropical, com verões quentes e úmidos, e invernos mais amenos. Durante o verão, é comum ocorrerem chuvas fortes especialmente durante a tarde e no início da noite. No inverno, as temperaturas são mais amenas, com menos chuva.
#
# Se você puder fornecer o período do ano ou a estação em que se encontra, posso tentar dar uma ideia mais geral sobre o que pode ser esperado em termos de temperatura e condições climáticas no Rio de Janeiro. Além disso, é sempre uma boa ideia verificar as condições atuais e a previsão para os próximos dias através de fontes meteorológicas oficiais para ter a informações mais precisas e atualizadas.
# Você: sair
# Encerrando chat. Até a próxima!

# %%
import requests
import json

# %%
def previsao_do_tempo(city, country):

  WHEATHER_API = userdata.get('WHEATHER_API')
  url = f'http://api.openweathermap.org/data/2.5/weather?q={city},{country}&APPID={WHEATHER_API}&lang=pt_br&units=metric'
  response = requests.get(url)
  data = response.json()
  return json.dumps(data)

# %%
previsao_do_tempo('Rio de Janeiro', 'BR')
# Out:
# '{"coord": {"lon": -43.2075, "lat": -22.9028}, "weather": [{"id": 803, "main": "Clouds", "description": "nublado", "icon": "04d"}], "base": "stations", "main": {"temp": 32, "feels_like": 33.24, "temp_min": 31.97, "temp_max": 32.12, "pressure": 1006, "humidity": 45, "sea_level": 1006, "grnd_level": 1007}, "visibility": 10000, "wind": {"speed": 3.6, "deg": 300}, "clouds": {"all": 75}, "dt": 1760385221, "sys": {"type": 1, "id": 8376, "country": "BR", "sunrise": 1760343708, "sunset": 1760388955}, "timezone": -10800, "id": 3451190, "name": "Rio de Janeiro", "cod": 200}'
